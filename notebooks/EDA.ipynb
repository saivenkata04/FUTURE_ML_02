# %%
import pandas as pd
from pathlib import Path

# Build a path that works whether the notebook is run from project root or notebooks/.
project_root = Path.cwd() if (Path.cwd() / "data").exists() else Path.cwd().parent
csv_path = project_root / "data" / "raw" / "customer_support_tickets.csv"

df = pd.read_csv(csv_path)
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %%
import pandas as pd

# Load the original dataset
df = pd.read_csv("../data/raw/customer_support_tickets.csv")

# Select only the required columns
df = df[[
    "Product Purchased",
    "Ticket Channel",
    "Ticket Subject",
    "Ticket Description",
    "Ticket Type",
    "Ticket Priority"
]]

# Display the first 5 rows
print(df.head())

# Check dataset information
print(df.info())

# Save the cleaned dataset
df.to_csv("../data/processed/cleaned_tickets.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
#   Product Purchased Ticket Channel            Ticket Subject  \
# 0        GoPro Hero   Social media             Product setup
# 1       LG Smart TV           Chat  Peripheral compatibility
# 2          Dell XPS   Social media           Network problem
# 3  Microsoft Office   Social media            Account access
# 4  Autodesk AutoCAD          Email                 Data loss
#
#                                   Ticket Description      Ticket Type  \
# 0  I'm having an issue with the {product_purchase...  Technical issue
# 1  I'm having an issue with the {product_purchase...  Technical issue
# 2  I'm facing a problem with my {product_purchase...  Technical issue
# 3  I'm having an issue with the {product_purchase...  Billing inquiry
# 4  I'm having an issue with the {product_purchase...  Billing inquiry
#
#   Ticket Priority
# 0        Critical
# 1        Critical
# 2             Low
# 3             Low
# 4             Low
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../data/processed/cleaned_tickets.csv")

# %%
print("First 5 Rows:")
df.head()
# Out:
# First 5 Rows:
#   Product Purchased Ticket Channel            Ticket Subject  \
# 0        GoPro Hero   Social media             Product setup
# 1       LG Smart TV           Chat  Peripheral compatibility
# 2          Dell XPS   Social media           Network problem
# 3  Microsoft Office   Social media            Account access
# 4  Autodesk AutoCAD          Email                 Data loss
#
#                                   Ticket Description      Ticket Type  \
# 0  I'm having an issue with the {product_purchase...  Technical issue
# 1  I'm having an issue with the {product_purchase...  Technical issue
# 2  I'm facing a problem with my {product_purchase...  Technical issue
# 3  I'm having an issue with the {product_purchase...  Billing inquiry
# 4  I'm having an issue with the {product_purchase...  Billing inquiry
#
#   Ticket Priority
# 0        Critical
# 1        Critical
# 2             Low
# 3             Low
# 4             Low

# %%
print("Last 5 Rows:")
df.tail()
# Out:
# Last 5 Rows:
#            Product Purchased Ticket Channel        Ticket Subject  \
# 8464                 LG OLED          Phone  Installation support
# 8465  Bose SoundLink Speaker          Email        Refund request
# 8466     GoPro Action Camera   Social media        Account access
# 8467             PlayStation          Email         Payment issue
# 8468      Philips Hue Lights          Phone        Hardware issue
#
#                                      Ticket Description      Ticket Type  \
# 8464  My {product_purchased} is making strange noise...  Product inquiry
# 8465  I'm having an issue with the {product_purchase...  Technical issue
# 8466  I'm having an issue with the {product_purchase...  Technical issue
# 8467  I'm having an issue with the {product_purchase...  Product inquiry
# 8468  There seems to be a hardware problem with my {...  Billing inquiry
#
#      Ticket Priority
# 8464             Low
# 8465        Critical
# 8466            High
# 8467          Medium
# ...

# %%
print("Dataset Shape")
print(df.shape)
# Out:
# Dataset Shape
# (8469, 6)

# %%
print("Dataset Information")
df.info()
# Out:
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8469 entries, 0 to 8468
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Product Purchased   8469 non-null   object
#  1   Ticket Channel      8469 non-null   object
#  2   Ticket Subject      8469 non-null   object
#  3   Ticket Description  8469 non-null   object
#  4   Ticket Type         8469 non-null   object
#  5   Ticket Priority     8469 non-null   object
# dtypes: object(6)
# memory usage: 397.1+ KB

# %%
print("Data Types")
df.dtypes
# Out:
# Data Types
# Product Purchased     object
# Ticket Channel        object
# Ticket Subject        object
# Ticket Description    object
# Ticket Type           object
# Ticket Priority       object
# dtype: object

# %%
print("Missing Values")
df.isnull().sum()
# Out:
# Missing Values
# Product Purchased     0
# Ticket Channel        0
# Ticket Subject        0
# Ticket Description    0
# Ticket Type           0
# Ticket Priority       0
# dtype: int64

# %%
print("Duplicate Records")
print(df.duplicated().sum())
# Out:
# Duplicate Records
# 1

# %%
df = df.drop_duplicates()

print("Dataset Shape After Removing Duplicates")
print(df.shape)
# Out:
# Dataset Shape After Removing Duplicates
# (8468, 6)

# %%
df.describe(include='all')
# Out:
#        Product Purchased Ticket Channel  Ticket Subject  \
# count               8468           8468            8468
# unique                42              4              16
# top            Canon EOS          Email  Refund request
# freq                 240           2143             576
#
#                                        Ticket Description     Ticket Type  \
# count                                                8468            8468
# unique                                               8077               5
# top     I'm having an issue with the {product_purchase...  Refund request
# freq                                                   25            1752
#
#        Ticket Priority
# count             8468
# unique               4
# top             Medium
# freq              2192

# %%
print("Ticket Type Distribution")

df["Ticket Type"].value_counts()
# Out:
# Ticket Type Distribution
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1694
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64

# %%
print("Ticket Priority Distribution")

df["Ticket Priority"].value_counts()
# Out:
# Ticket Priority Distribution
# Ticket Priority
# Medium      2192
# Critical    2128
# High        2085
# Low         2063
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

df["Ticket Type"].value_counts().plot(kind='bar')

plt.title("Ticket Type Distribution")
plt.xlabel("Ticket Type")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(6,4))

df["Ticket Priority"].value_counts().plot(kind='bar')

plt.title("Ticket Priority Distribution")
plt.xlabel("Priority")
plt.ylabel("Count")

plt.show()

# %%
df["Subject Length"] = df["Ticket Subject"].str.len()

df["Subject Length"].head()
# Out:
# 0    13
# 1    24
# 2    15
# 3    14
# 4     9
# Name: Subject Length, dtype: int64

# %%
df["Description Length"] = df["Ticket Description"].str.len()

df["Description Length"].head()
# Out:
# 0    284
# 1    282
# 2    275
# 3    262
# 4    333
# Name: Description Length, dtype: int64

# %%
df["Subject Length"].describe()
# Out:
# count    8468.000000
# mean       15.725083
# std         4.108744
# min         9.000000
# 25%        13.000000
# 50%        14.000000
# 75%        20.000000
# max        24.000000
# Name: Subject Length, dtype: float64

# %%
df["Description Length"].describe()
# Out:
# count    8468.000000
# mean      289.836089
# std        43.577075
# min       151.000000
# 25%       273.000000
# 50%       298.000000
# 75%       318.000000
# max       397.000000
# Name: Description Length, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Subject Length"], bins=30)

plt.title("Subject Length Distribution")
plt.xlabel("Characters")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Description Length"], bins=30)

plt.title("Description Length Distribution")
plt.xlabel("Characters")
plt.ylabel("Frequency")

plt.show()

# %%
top_ticket = df["Ticket Type"].value_counts()

print(top_ticket)
# Out:
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1694
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64

# %%
top_priority = df["Ticket Priority"].value_counts()

print(top_priority)
# Out:
# Ticket Priority
# Medium      2192
# Critical    2128
# High        2085
# Low         2063
# Name: count, dtype: int64

# %%
print("Empty Subjects")

print((df["Ticket Subject"].str.strip() == "").sum())

print()

print("Empty Descriptions")

print((df["Ticket Description"].str.strip() == "").sum())
# Out:
# Empty Subjects
# 0
#
# Empty Descriptions
# 0

# %%
df["Text"] = df["Ticket Subject"] + " " + df["Ticket Description"]

df[["Text"]].head()
# Out:
#                                                 Text
# 0  Product setup I'm having an issue with the {pr...
# 1  Peripheral compatibility I'm having an issue w...
# 2  Network problem I'm facing a problem with my {...
# 3  Account access I'm having an issue with the {p...
# 4  Data loss I'm having an issue with the {produc...

# %%
df["Text Length"] = df["Text"].str.len()

df["Text Length"].describe()
# Out:
# count    8468.000000
# mean      306.561171
# std        43.791821
# min       161.000000
# 25%       289.000000
# 50%       315.000000
# 75%       335.000000
# max       414.000000
# Name: Text Length, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Text Length"], bins=30)

plt.title("Combined Text Length Distribution")

plt.xlabel("Characters")

plt.ylabel("Frequency")

plt.show()

# %%
df.to_csv("../data/processed/cleaned_tickets.csv", index=False)

print("EDA Completed Successfully")
# Out:
# EDA Completed Successfully

# %%
import re
import string
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# True

# %%
import pandas as pd

df = pd.read_csv("../data/processed/cleaned_tickets.csv")

# %%
df["Text"] = (
    df["Ticket Subject"].fillna("") +
    " " +
    df["Ticket Description"].fillna("")
)

# %%
stop_words = set(stopwords.words("english"))

lemmatizer = WordNetLemmatizer()

# %%
def clean_text(text):

    text = text.lower()

    text = re.sub(r"http\S+|www\S+", "", text)

    text = re.sub(r"\d+", "", text)

    text = text.translate(str.maketrans("", "", string.punctuation))

    text = re.sub(r"\s+", " ", text).strip()

    words = text.split()

    words = [word for word in words if word not in stop_words]

    words = [lemmatizer.lemmatize(word) for word in words]

    return " ".join(words)

# %%
df["Clean_Text"] = df["Text"].apply(clean_text)

# %%
df[["Text", "Clean_Text"]].head(10)
# Out:
#                                                 Text  \
# 0  Product setup I'm having an issue with the {pr...
# 1  Peripheral compatibility I'm having an issue w...
# 2  Network problem I'm facing a problem with my {...
# 3  Account access I'm having an issue with the {p...
# 4  Data loss I'm having an issue with the {produc...
# 5  Payment issue I'm facing a problem with my {pr...
# 6  Refund request I'm unable to access my {produc...
# 7  Battery life I'm having an issue with the {pro...
# 8  Installation support I'm having an issue with ...
# 9  Payment issue My {product_purchased} is making...
#
#                                           Clean_Text
# 0  product setup im issue productpurchased please...
# 1  peripheral compatibility im issue productpurch...
# 2  network problem im facing problem productpurch...
# 3  account access im issue productpurchased pleas...
# 4  data loss im issue productpurchased please ass...
# 5  payment issue im facing problem productpurchas...
# ...

# %%
(df["Clean_Text"] == "").sum()
# Out:
# np.int64(0)

# %%
df = df[df["Clean_Text"] != ""]

# %%
df.to_csv("../data/processed/preprocessed_tickets.csv", index=False)

print("Text preprocessing completed successfully!")
# Out:
# Text preprocessing completed successfully!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

df = pd.read_csv("../data/processed/preprocessed_tickets.csv")

# %%
X = df["Clean_Text"]

# %%
y_category = df["Ticket Type"]

# %%
y_priority = df["Ticket Priority"]

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1,2),
    stop_words='english'
)

# %%
X_tfidf = tfidf.fit_transform(X)

# %%
print(X_tfidf.shape)
# Out:
# (8468, 5000)

# %%
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(
    X_tfidf,
    y_category,
    test_size=0.2,
    random_state=42
)

# %%
X_train_pri, X_test_pri, y_train_pri, y_test_pri = train_test_split(
    X_tfidf,
    y_priority,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.model_selection import train_test_split

# %%
X = X_tfidf

y_category = df["Ticket Type"]
y_priority = df["Ticket Priority"]

# %%
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(
    X,
    y_category,
    test_size=0.2,
    random_state=42,
    stratify=y_category
)

# %%
X_train_pri, X_test_pri, y_train_pri, y_test_pri = train_test_split(
    X,
    y_priority,
    test_size=0.2,
    random_state=42,
    stratify=y_priority
)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

# %%
nb_category = MultinomialNB()

nb_category.fit(X_train_cat, y_train_cat)
# Out:
# MultinomialNB()

# %%
lr_category = LogisticRegression(max_iter=1000)

lr_category.fit(X_train_cat, y_train_cat)
# Out:
# LogisticRegression(max_iter=1000)

# %%
svm_category = LinearSVC()

svm_category.fit(X_train_cat, y_train_cat)
# Out:
# LinearSVC()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
pred_nb = nb_category.predict(X_test_cat)

print("Naive Bayes Accuracy")
print(accuracy_score(y_test_cat, pred_nb))

print(classification_report(y_test_cat, pred_nb))
# Out:
# Naive Bayes Accuracy
# 0.20602125147579692
#                       precision    recall  f1-score   support
#
#      Billing inquiry       0.21      0.17      0.19       327
# Cancellation request       0.22      0.20      0.21       339
#      Product inquiry       0.21      0.18      0.19       328
#       Refund request       0.19      0.23      0.21       351
#      Technical issue       0.21      0.25      0.23       349
#
#             accuracy                           0.21      1694
#            macro avg       0.21      0.21      0.20      1694
#         weighted avg       0.21      0.21      0.21      1694

# %%
pred_lr = lr_category.predict(X_test_cat)

print("Logistic Regression Accuracy")
print(accuracy_score(y_test_cat, pred_lr))

print(classification_report(y_test_cat, pred_lr))
# Out:
# Logistic Regression Accuracy
# 0.21074380165289255
#                       precision    recall  f1-score   support
#
#      Billing inquiry       0.21      0.20      0.21       327
# Cancellation request       0.20      0.21      0.20       339
#      Product inquiry       0.22      0.21      0.22       328
#       Refund request       0.17      0.18      0.18       351
#      Technical issue       0.25      0.25      0.25       349
#
#             accuracy                           0.21      1694
#            macro avg       0.21      0.21      0.21      1694
#         weighted avg       0.21      0.21      0.21      1694

# %%
pred_svm = svm_category.predict(X_test_cat)

print("Linear SVM Accuracy")
print(accuracy_score(y_test_cat, pred_svm))

print(classification_report(y_test_cat, pred_svm))
# Out:
# Linear SVM Accuracy
# 0.22786304604486424
#                       precision    recall  f1-score   support
#
#      Billing inquiry       0.24      0.25      0.24       327
# Cancellation request       0.23      0.24      0.24       339
#      Product inquiry       0.23      0.22      0.23       328
#       Refund request       0.19      0.19      0.19       351
#      Technical issue       0.25      0.24      0.24       349
#
#             accuracy                           0.23      1694
#            macro avg       0.23      0.23      0.23      1694
#         weighted avg       0.23      0.23      0.23      1694

# %%
nb_priority = MultinomialNB()
nb_priority.fit(X_train_pri, y_train_pri)
# Out:
# MultinomialNB()

# %%
lr_priority = LogisticRegression(max_iter=1000)
lr_priority.fit(X_train_pri, y_train_pri)
# Out:
# LogisticRegression(max_iter=1000)

# %%
svm_priority = LinearSVC()
svm_priority.fit(X_train_pri, y_train_pri)
# Out:
# LinearSVC()

# %%
import joblib
from pathlib import Path

# Pick models if "best_*" variables don't exist in the current session.
category_model = globals().get("best_category_model", globals().get("svm_category", globals().get("lr_category", globals().get("nb_category"))))
priority_model = globals().get("best_priority_model", globals().get("svm_priority", globals().get("lr_priority", globals().get("nb_priority"))))

if category_model is None or priority_model is None:
    raise NameError("No trained category/priority model found. Run the training cells first.")

project_root = Path.cwd() if (Path.cwd() / "models").exists() else Path.cwd().parent
models_dir = project_root / "models"
models_dir.mkdir(parents=True, exist_ok=True)

joblib.dump(category_model, models_dir / "category_model.pkl")
joblib.dump(priority_model, models_dir / "priority_model.pkl")
joblib.dump(tfidf, models_dir / "tfidf_vectorizer.pkl")

print("Models saved to:", models_dir)
# Out:
# Models saved to: c:\Users\venka\OneDrive\Desktop\Task2\Support-Ticket-Classification\models

# %%
import joblib

# Save Ticket Type model
joblib.dump(svm_category, "../models/category_model.pkl")

# Save Ticket Priority model
joblib.dump(svm_priority, "../models/priority_model.pkl")

# Save TF-IDF Vectorizer
joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")

print("Models Saved Successfully!")
# Out:
# Models Saved Successfully!

# %%
import joblib

category_model = joblib.load("../models/category_model.pkl")
priority_model = joblib.load("../models/priority_model.pkl")
tfidf = joblib.load("../models/tfidf_vectorizer.pkl")

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def clean_text(text):

    text = text.lower()

    text = re.sub(r"http\S+|www\S+", "", text)

    text = re.sub(r"\d+", "", text)

    text = text.translate(str.maketrans("", "", string.punctuation))

    words = text.split()

    words = [word for word in words if word not in stop_words]

    words = [lemmatizer.lemmatize(word) for word in words]

    return " ".join(words)

# %%
def predict_ticket(ticket):

    ticket = clean_text(ticket)

    vector = tfidf.transform([ticket])

    category = category_model.predict(vector)[0]

    priority = priority_model.predict(vector)[0]

    print("Predicted Category :", category)
    print("Predicted Priority :", priority)

# %%
predict_ticket("I forgot my account password and cannot login.")
# Out:
# Predicted Category : Billing inquiry
# Predicted Priority : High

# %%
predict_ticket("Payment was deducted twice but my order was not confirmed.")
# Out:
# Predicted Category : Technical issue
# Predicted Priority : Low

# %%
predict_ticket("My laptop screen becomes blank whenever I start it.")
# Out:
# Predicted Category : Product inquiry
# Predicted Priority : High

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_estimator(
    svm_category,
    X_test_cat,
    y_test_cat,
    xticks_rotation=45
)

plt.title("Ticket Type Confusion Matrix")
plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(
    svm_priority,
    X_test_pri,
    y_test_pri
)

plt.title("Priority Confusion Matrix")
plt.show()

# %%
classification_report(y_test_cat, pred_svm)
# Out:
# '                      precision    recall  f1-score   support\n\n     Billing inquiry       0.24      0.25      0.24       327\nCancellation request       0.23      0.24      0.24       339\n     Product inquiry       0.23      0.22      0.23       328\n      Refund request       0.19      0.19      0.19       351\n     Technical issue       0.25      0.24      0.24       349\n\n            accuracy                           0.23      1694\n           macro avg       0.23      0.23      0.23      1694\n        weighted avg       0.23      0.23      0.23      1694\n'

# %%
pred_svm_priority = svm_priority.predict(X_test_pri)
classification_report(y_test_pri, pred_svm_priority)
# Out:
# c:\Users\venka\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\venka\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\venka\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
import os

os.makedirs("../reports", exist_ok=True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
df["Ticket Type"].value_counts().plot(kind="bar")

plt.title("Ticket Type Distribution")
plt.xlabel("Ticket Type")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig("../reports/ticket_type_distribution.png", dpi=300)

plt.show()

# %%
plt.figure(figsize=(6,4))

df["Ticket Priority"].value_counts().plot(kind="bar")

plt.title("Priority Distribution")
plt.xlabel("Priority")
plt.ylabel("Count")

plt.tight_layout()

plt.savefig("../reports/priority_distribution.png", dpi=300)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Text Length"], bins=30)

plt.title("Text Length Distribution")
plt.xlabel("Characters")
plt.ylabel("Frequency")

plt.tight_layout()

plt.savefig("../reports/text_length_distribution.png", dpi=300)

plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(
    svm_category,
    X_test_cat,
    y_test_cat,
    xticks_rotation=45
)

plt.title("Category Confusion Matrix")

plt.tight_layout()

plt.savefig("../reports/confusion_matrix_category.png", dpi=300)

plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(
    svm_priority,
    X_test_pri,
    y_test_pri
)

plt.title("Priority Confusion Matrix")

plt.tight_layout()

plt.savefig("../reports/confusion_matrix_priority.png", dpi=300)

plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test_cat, pred_svm)

with open("../reports/classification_report_category.txt", "w") as file:
    file.write(report)

print(report)
# Out:
#                       precision    recall  f1-score   support
#
#      Billing inquiry       0.24      0.25      0.24       327
# Cancellation request       0.23      0.24      0.24       339
#      Product inquiry       0.23      0.22      0.23       328
#       Refund request       0.19      0.19      0.19       351
#      Technical issue       0.25      0.24      0.24       349
#
#             accuracy                           0.23      1694
#            macro avg       0.23      0.23      0.23      1694
#         weighted avg       0.23      0.23      0.23      1694

# %%
pred_svm_priority = globals().get("pred_svm_priority", svm_priority.predict(X_test_pri))
report = classification_report(y_test_pri, pred_svm_priority)

with open("../reports/classification_report_priority.txt", "w") as file:
    file.write(report)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#     Critical       0.26      0.26      0.26       426
#         High       0.25      0.24      0.24       417
#          Low       0.23      0.24      0.24       413
#       Medium       0.28      0.29      0.28       438
#
#     accuracy                           0.26      1694
#    macro avg       0.26      0.26      0.26      1694
# weighted avg       0.26      0.26      0.26      1694

# %%
pred_svm_priority = globals().get("pred_svm_priority", svm_priority.predict(X_test_pri))

with open("../reports/model_results.txt", "w") as file:

    file.write("Support Ticket Classification Results\n")
    file.write("="*40 + "\n\n")

    file.write(f"Category Model Accuracy : {accuracy_score(y_test_cat, pred_svm):.4f}\n")
    file.write(f"Priority Model Accuracy : {accuracy_score(y_test_pri, pred_svm_priority):.4f}\n")

print("Results Saved")
# Out:
# Results Saved

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": [
        "Naive Bayes",
        "Logistic Regression",
        "Linear SVM"
    ],
    "Category Accuracy": [
        accuracy_nb_cat,
        accuracy_lr_cat,
        accuracy_svm_cat
    ],
    "Priority Accuracy": [
        accuracy_nb_pri,
        accuracy_lr_pri,
        accuracy_svm_pri
    ]
})

comparison.to_csv("../reports/model_comparison.csv", index=False)

comparison
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 10
#       6         "Logistic Regression",
#       7         "Linear SVM"
#       8     ],
#       9     "Category Accuracy": [
# ---> 10         accuracy_nb_cat,
#      11         accuracy_lr_cat,
#      12         accuracy_svm_cat
#      13     ],
#
# NameError: name 'accuracy_nb_cat' is not defined

# %%
from sklearn.metrics import accuracy_score

# Category Model Accuracies
accuracy_nb_cat = accuracy_score(y_test_cat, pred_nb)
accuracy_lr_cat = accuracy_score(y_test_cat, pred_lr)
accuracy_svm_cat = accuracy_score(y_test_cat, pred_svm)

print("Naive Bayes:", accuracy_nb_cat)
print("Logistic Regression:", accuracy_lr_cat)
print("Linear SVM:", accuracy_svm_cat)
# Out:
# Naive Bayes: 0.20602125147579692
# Logistic Regression: 0.21074380165289255
# Linear SVM: 0.22786304604486424

# %%
# Priority Model Accuracies
accuracy_nb_pri = accuracy_score(y_test_pri, pred_nb_priority)
accuracy_lr_pri = accuracy_score(y_test_pri, pred_lr_priority)
accuracy_svm_pri = accuracy_score(y_test_pri, pred_svm_priority)

print("Naive Bayes:", accuracy_nb_pri)
print("Logistic Regression:", accuracy_lr_pri)
print("Linear SVM:", accuracy_svm_pri)
# Out:
# Naive Bayes: 0.24793388429752067
# Logistic Regression: 0.2514757969303424
# Linear SVM: 0.256198347107438

# %%
pred_nb_priority = nb_priority.predict(X_test_pri)

# %%
pred_lr_priority = lr_priority.predict(X_test_pri)

# %%
pred_svm_priority = svm_priority.predict(X_test_pri)

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": [
        "Naive Bayes",
        "Logistic Regression",
        "Linear SVM"
    ],
    "Category Accuracy": [
        accuracy_nb_cat,
        accuracy_lr_cat,
        accuracy_svm_cat
    ],
    "Priority Accuracy": [
        accuracy_nb_pri,
        accuracy_lr_pri,
        accuracy_svm_pri
    ]
})

comparison
# Out:
#                  Model  Category Accuracy  Priority Accuracy
# 0          Naive Bayes           0.206021           0.247934
# 1  Logistic Regression           0.210744           0.251476
# 2           Linear SVM           0.227863           0.256198

# %%
comparison.to_csv("../reports/model_comparison.csv", index=False)

print("Model comparison saved successfully!")
# Out:
# Model comparison saved successfully!

# %%
pip install reportlab
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 9.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.3 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from reportlab.platypus import SimpleDocTemplate, Paragraph
from reportlab.lib.styles import getSampleStyleSheet
import os

# Create reports folder if it doesn't exist
os.makedirs("../reports", exist_ok=True)

# Create PDF
doc = SimpleDocTemplate("../reports/Project_Report.pdf")

styles = getSampleStyleSheet()

story = []

# Title
story.append(Paragraph("<b><font size=18>Support Ticket Classification & Prioritization</font></b>", styles["Title"]))

story.append(Paragraph("<br/>", styles["Normal"]))

# Objective
story.append(Paragraph("<b>1. Project Objective</b>", styles["Heading2"]))
story.append(Paragraph(
    "The objective of this project is to automatically classify customer support tickets into different categories "
    "and predict their priority level using Natural Language Processing (NLP) and Machine Learning. "
    "This helps organizations reduce manual effort, improve response times, and efficiently manage customer issues.",
    styles["BodyText"]
))

# Dataset
story.append(Paragraph("<b>2. Dataset</b>", styles["Heading2"]))
story.append(Paragraph(
    "Dataset Used: Customer Support Ticket Dataset (Kaggle)<br/>"
    "Input Features:<br/>"
    "- Ticket Subject<br/>"
    "- Ticket Description<br/><br/>"
    "Target Variables:<br/>"
    "- Ticket Type<br/>"
    "- Ticket Priority",
    styles["BodyText"]
))

# EDA
story.append(Paragraph("<b>3. Exploratory Data Analysis (EDA)</b>", styles["Heading2"]))
story.append(Paragraph(
    "EDA was performed to understand the dataset. The following analyses were completed:<br/>"
    "- Dataset shape and structure<br/>"
    "- Missing value analysis<br/>"
    "- Duplicate record detection<br/>"
    "- Ticket Type distribution<br/>"
    "- Ticket Priority distribution<br/>"
    "- Ticket text length analysis",
    styles["BodyText"]
))

# Preprocessing
story.append(Paragraph("<b>4. Text Preprocessing</b>", styles["Heading2"]))
story.append(Paragraph(
    "The ticket text was preprocessed using standard NLP techniques including:<br/>"
    "- Lowercase conversion<br/>"
    "- Removal of punctuation and numbers<br/>"
    "- Stopword removal<br/>"
    "- Lemmatization<br/>"
    "- Combining ticket subject and description",
    styles["BodyText"]
))

# Feature Engineering
story.append(Paragraph("<b>5. Feature Engineering</b>", styles["Heading2"]))
story.append(Paragraph(
    "TF-IDF Vectorization was used to convert textual ticket data into numerical feature vectors suitable for machine learning models.",
    styles["BodyText"]
))

# Models
story.append(Paragraph("<b>6. Machine Learning Models</b>", styles["Heading2"]))
story.append(Paragraph(
    "The following models were trained and evaluated:<br/>"
    "- Multinomial Naive Bayes<br/>"
    "- Logistic Regression<br/>"
    "- Linear Support Vector Machine (Linear SVM)",
    styles["BodyText"]
))

# Evaluation
story.append(Paragraph("<b>7. Model Evaluation</b>", styles["Heading2"]))
story.append(Paragraph(
    "Models were evaluated using:<br/>"
    "- Accuracy<br/>"
    "- Precision<br/>"
    "- Recall<br/>"
    "- F1-Score<br/>"
    "- Confusion Matrix",
    styles["BodyText"]
))

# Results
story.append(Paragraph("<b>8. Results</b>", styles["Heading2"]))
story.append(Paragraph(
    "The best-performing models were selected based on evaluation metrics. "
    "The trained models can automatically predict both the ticket category and its priority.",
    styles["BodyText"]
))

# Business Impact
story.append(Paragraph("<b>9. Business Impact</b>", styles["Heading2"]))
story.append(Paragraph(
    "- Reduces manual ticket sorting.<br/>"
    "- Improves support response time.<br/>"
    "- Prioritizes urgent customer issues.<br/>"
    "- Enhances customer satisfaction.<br/>"
    "- Increases operational efficiency.",
    styles["BodyText"]
))

# Conclusion
story.append(Paragraph("<b>10. Conclusion</b>", styles["Heading2"]))
story.append(Paragraph(
    "This project demonstrates an end-to-end NLP workflow for automating support ticket classification and prioritization. "
    "The developed solution can assist support teams in efficiently managing large volumes of customer requests.",
    styles["BodyText"]
))

# Build PDF
doc.build(story)

print("Project_Report.pdf created successfully!")
# Out:
# Project_Report.pdf created successfully!
